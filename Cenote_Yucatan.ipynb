# %% [markdown]
# # LIBRERÍAS PARA EL PROYECTO

# %%
import pandas as pd
#importamos la libreria de panta

# %% [markdown]
# # EXTRACT - Extraer

# %%
url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vQWYG68ilCqAlSzdATYFK-q1i1ls_hPWkQpSTb1k6BS2I6bLgsnXlbLEIIuJox2X5mj0yB2NUdJof5b/pub?output=csv'
#esta url se extrajo de la nube google drive que es donde se almacen los datos del RFID.

# %%
df_drive = pd.read_csv(url)
#esto nos permite poder visualizar desde python el archivo en la nube

# %%
df_drive.head()
#exploramos su contenido
# Out:
#                  Date  Card UID    Name     Access         From
# 0  09/03/2020 9:40:15  41d716a3  Javier  permitido  headquarter

# %%
ruta= "Datos_cenote"
df_drive.to_csv(ruta)
#en este paso, nos descarga el csv para poder editarlo o visualizarlo con el nombre Datos_cenote.

# %%
url2 = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vR-yW1xjxWfR40eoYCoFLSKzoLkniAFSCrripBZw7ElZomUI9NsCcFrzwsIvZtsEXCLrv3im9E1QeWn/pub?output=csv'

# %%
df_editar = pd.read_csv(url2)

# %%
df_editar.head(15)
# Out:
#                   Date  Card UID      Name     Access         From
# 0   09/03/2020 9:40:15  41d716a3    Javier  permitido  headquarter
# 1   10/03/2020 9:40:15  40d817a6    Lucely  permitido  headquarter
# 2   11/03/2020 9:40:15  34d923a5  Santiago  permitido  headquarter
# 3   12/03/2020 9:40:15  12r623a5   Mildred  permitido  headquarter
# 4   13/03/2020 9:40:15  45v712a5      Lian  permitido  headquarter
# 5   14/03/2020 9:40:15  23c535s7     Josue  permitido  headquarter
# 6   15/03/2020 9:40:15  48c7ass9   Lizzeth  permitido  headquarter
# 7   16/03/2020 9:40:15  38c3ass9   Daniela  permitido  headquarter
# 8   17/03/2020 9:40:15  29c4aq34   Roberto  permitido  headquarter
# 9   18/03/2020 9:40:15  78c445as     Elias  permitido  headquarter
# 10  19/03/2020 9:40:15  45e734at     Maria  permitido  headquarter
# 11  20/03/2020 9:40:15  23e545as      Elsi  permitido  headquarter
# 12  21/03/2020 9:40:15  34e523et    Monica  permitido  headquarter
# 13  22/03/2020 9:40:15  12e889er   Angeles  permitido  headquarter

# %%
ruta_editar = "datos_inv"
df_editar.to_csv(ruta)

# %%
# !ls
#comprobamos el archivo se descargo.
# Out:
# 'Cenote_Yucatan .ipynb'   Datos_cenote

# %%
df_drive = pd.read_csv('Datos_cenote')
#seleccionamos el archivo para poder ver su contenido

# %%
df_drive.head(20)
#comprobamos que el archivo descargado tiene una tabla con un solo dato.
# Out:
#     Unnamed: 0                Date  Card UID      Name     Access         From
# 0            0  09/03/2020 9:40:15  41d716a3    Javier  permitido  headquarter
# 1            1  10/03/2020 9:40:15  40d817a6    Lucely  permitido  headquarter
# 2            2  11/03/2020 9:40:15  34d923a5  Santiago  permitido  headquarter
# 3            3  12/03/2020 9:40:15  12r623a5   Mildred  permitido  headquarter
# 4            4  13/03/2020 9:40:15  45v712a5      Lian  permitido  headquarter
# 5            5  14/03/2020 9:40:15  23c535s7     Josue  permitido  headquarter
# 6            6  15/03/2020 9:40:15  48c7ass9   Lizzeth  permitido  headquarter
# 7            7  16/03/2020 9:40:15  38c3ass9   Daniela  permitido  headquarter
# 8            8  17/03/2020 9:40:15  29c4aq34   Roberto  permitido  headquarter
# 9            9  18/03/2020 9:40:15  78c445as     Elias  permitido  headquarter
# 10          10  19/03/2020 9:40:15  45e734at     Maria  permitido  headquarter
# 11          11  20/03/2020 9:40:15  23e545as      Elsi  permitido  headquarter
# 12          12  21/03/2020 9:40:15  34e523et    Monica  permitido  headquarter
# 13          13  22/03/2020 9:40:15  12e889er   Angeles  permitido  headquarter

# %%
df_drive.columns
#observamos unicamente las columnas del archivo.
# Out:
# Index(['Unnamed: 0', 'Date', 'Card UID', 'Name', 'Access', 'From'], dtype='object')

# %%
Nombre = df_drive['Name'].unique()
print(sorted(Nombre))
#con esto podemos observar el nombre de las personas que han ingresado.
# Out:
# ['Angeles', 'Daniela', 'Elias', 'Elsi', 'Javier', 'Josue', 'Lian', 'Lizzeth', 'Lucely', 'Maria', 'Mildred', 'Monica', 'Roberto', 'Santiago']

# %%
dato = df_drive['Date'].unique()
print(sorted(dato))
#con esto podemos observar la fecha y la hora que las personas accedieron.
# Out:
# ['09/03/2020 9:40:15', '10/03/2020 9:40:15', '11/03/2020 9:40:15', '12/03/2020 9:40:15', '13/03/2020 9:40:15', '14/03/2020 9:40:15', '15/03/2020 9:40:15', '16/03/2020 9:40:15', '17/03/2020 9:40:15', '18/03/2020 9:40:15', '19/03/2020 9:40:15', '20/03/2020 9:40:15', '21/03/2020 9:40:15', '22/03/2020 9:40:15']

# %%
pd.concat([df_drive, df_editar,], axis=1)
#de esta forma concatenamos los datos de los dos dataframe, solo que no mantiene un orden.
# Out:
#     Unnamed: 0                Date  Card UID      Name     Access  \
# 0            0  09/03/2020 9:40:15  41d716a3    Javier  permitido
# 1            1  10/03/2020 9:40:15  40d817a6    Lucely  permitido
# 2            2  11/03/2020 9:40:15  34d923a5  Santiago  permitido
# 3            3  12/03/2020 9:40:15  12r623a5   Mildred  permitido
# 4            4  13/03/2020 9:40:15  45v712a5      Lian  permitido
# 5            5  14/03/2020 9:40:15  23c535s7     Josue  permitido
# 6            6  15/03/2020 9:40:15  48c7ass9   Lizzeth  permitido
# 7            7  16/03/2020 9:40:15  38c3ass9   Daniela  permitido
# 8            8  17/03/2020 9:40:15  29c4aq34   Roberto  permitido
# 9            9  18/03/2020 9:40:15  78c445as     Elias  permitido
# 10          10  19/03/2020 9:40:15  45e734at     Maria  permitido
# 11          11  20/03/2020 9:40:15  23e545as      Elsi  permitido
# 12          12  21/03/2020 9:40:15  34e523et    Monica  permitido
# 13          13  22/03/2020 9:40:15  12e889er   Angeles  permitido
#
#            From                Date  Card UID      Name     Access  \
# 0   headquarter  09/03/2020 9:40:15  41d716a3    Javier  permitido
# 1   headquarter  10/03/2020 9:40:15  40d817a6    Lucely  permitido
# 2   headquarter  11/03/2020 9:40:15  34d923a5  Santiago  permitido
# 3   headquarter  12/03/2020 9:40:15  12r623a5   Mildred  permitido
# 4   headquarter  13/03/2020 9:40:15  45v712a5      Lian  permitido
# 5   headquarter  14/03/2020 9:40:15  23c535s7     Josue  permitido
# 6   headquarter  15/03/2020 9:40:15  48c7ass9   Lizzeth  permitido
# 7   headquarter  16/03/2020 9:40:15  38c3ass9   Daniela  permitido
# 8   headquarter  17/03/2020 9:40:15  29c4aq34   Roberto  permitido
# 9   headquarter  18/03/2020 9:40:15  78c445as     Elias  permitido
# 10  headquarter  19/03/2020 9:40:15  45e734at     Maria  permitido
# 11  headquarter  20/03/2020 9:40:15  23e545as      Elsi  permitido
# 12  headquarter  21/03/2020 9:40:15  34e523et    Monica  permitido
# 13  headquarter  22/03/2020 9:40:15  12e889er   Angeles  permitido
#
#            From
# 0   headquarter
# 1   headquarter
# 2   headquarter
# 3   headquarter
# 4   headquarter
# 5   headquarter
# 6   headquarter
# 7   headquarter
# 8   headquarter
# 9   headquarter
# 10  headquarter
# 11  headquarter
# 12  headquarter
# 13  headquarter

# %%
pd.concat([df_drive, df_editar,])
#De este modo la informacion de los dos dataframe se unen porque compara si tiene datos en la tabla iguales.
#OJO el mensaje nos informa una advertencia que en futuras versiones no lo ordenaria.
# Out:
# <ipython-input-17-ae642dfe7bf8>:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   pd.concat([df_drive, df_editar,])
#        Access  Card UID                Date         From      Name  Unnamed: 0
# 0   permitido  41d716a3  09/03/2020 9:40:15  headquarter    Javier         0.0
# 1   permitido  40d817a6  10/03/2020 9:40:15  headquarter    Lucely         1.0
# 2   permitido  34d923a5  11/03/2020 9:40:15  headquarter  Santiago         2.0
# 3   permitido  12r623a5  12/03/2020 9:40:15  headquarter   Mildred         3.0
# 4   permitido  45v712a5  13/03/2020 9:40:15  headquarter      Lian         4.0
# 5   permitido  23c535s7  14/03/2020 9:40:15  headquarter     Josue         5.0
# 6   permitido  48c7ass9  15/03/2020 9:40:15  headquarter   Lizzeth         6.0
# 7   permitido  38c3ass9  16/03/2020 9:40:15  headquarter   Daniela         7.0
# 8   permitido  29c4aq34  17/03/2020 9:40:15  headquarter   Roberto         8.0
# 9   permitido  78c445as  18/03/2020 9:40:15  headquarter     Elias         9.0
# 10  permitido  45e734at  19/03/2020 9:40:15  headquarter     Maria        10.0
# 11  permitido  23e545as  20/03/2020 9:40:15  headquarter      Elsi        11.0
# 12  permitido  34e523et  21/03/2020 9:40:15  headquarter    Monica        12.0
# 13  permitido  12e889er  22/03/2020 9:40:15  headquarter   Angeles        13.0
# 0   permitido  41d716a3  09/03/2020 9:40:15  headquarter    Javier         NaN
# 1   permitido  40d817a6  10/03/2020 9:40:15  headquarter    Lucely         NaN
# 2   permitido  34d923a5  11/03/2020 9:40:15  headquarter  Santiago         NaN
# 3   permitido  12r623a5  12/03/2020 9:40:15  headquarter   Mildred         NaN
# 4   permitido  45v712a5  13/03/2020 9:40:15  headquarter      Lian         NaN
# 5   permitido  23c535s7  14/03/2020 9:40:15  headquarter     Josue         NaN
# 6   permitido  48c7ass9  15/03/2020 9:40:15  headquarter   Lizzeth         NaN
# 7   permitido  38c3ass9  16/03/2020 9:40:15  headquarter   Daniela         NaN
# 8   permitido  29c4aq34  17/03/2020 9:40:15  headquarter   Roberto         NaN
# 9   permitido  78c445as  18/03/2020 9:40:15  headquarter     Elias         NaN
# 10  permitido  45e734at  19/03/2020 9:40:15  headquarter     Maria         NaN
# 11  permitido  23e545as  20/03/2020 9:40:15  headquarter      Elsi         NaN
# 12  permitido  34e523et  21/03/2020 9:40:15  headquarter    Monica         NaN
# 13  permitido  12e889er  22/03/2020 9:40:15  headquarter   Angeles         NaN

# %%
pd.concat([df_drive, df_editar,],sort=True)
#corregimos el mensaje con sort=true para que si ordene los dos dataframe, y silencie la advertencia.
# Out:
#        Access  Card UID                Date         From      Name  Unnamed: 0
# 0   permitido  41d716a3  09/03/2020 9:40:15  headquarter    Javier         0.0
# 1   permitido  40d817a6  10/03/2020 9:40:15  headquarter    Lucely         1.0
# 2   permitido  34d923a5  11/03/2020 9:40:15  headquarter  Santiago         2.0
# 3   permitido  12r623a5  12/03/2020 9:40:15  headquarter   Mildred         3.0
# 4   permitido  45v712a5  13/03/2020 9:40:15  headquarter      Lian         4.0
# 5   permitido  23c535s7  14/03/2020 9:40:15  headquarter     Josue         5.0
# 6   permitido  48c7ass9  15/03/2020 9:40:15  headquarter   Lizzeth         6.0
# 7   permitido  38c3ass9  16/03/2020 9:40:15  headquarter   Daniela         7.0
# 8   permitido  29c4aq34  17/03/2020 9:40:15  headquarter   Roberto         8.0
# 9   permitido  78c445as  18/03/2020 9:40:15  headquarter     Elias         9.0
# 10  permitido  45e734at  19/03/2020 9:40:15  headquarter     Maria        10.0
# 11  permitido  23e545as  20/03/2020 9:40:15  headquarter      Elsi        11.0
# 12  permitido  34e523et  21/03/2020 9:40:15  headquarter    Monica        12.0
# 13  permitido  12e889er  22/03/2020 9:40:15  headquarter   Angeles        13.0
# 0   permitido  41d716a3  09/03/2020 9:40:15  headquarter    Javier         NaN
# 1   permitido  40d817a6  10/03/2020 9:40:15  headquarter    Lucely         NaN
# 2   permitido  34d923a5  11/03/2020 9:40:15  headquarter  Santiago         NaN
# 3   permitido  12r623a5  12/03/2020 9:40:15  headquarter   Mildred         NaN
# 4   permitido  45v712a5  13/03/2020 9:40:15  headquarter      Lian         NaN
# 5   permitido  23c535s7  14/03/2020 9:40:15  headquarter     Josue         NaN
# 6   permitido  48c7ass9  15/03/2020 9:40:15  headquarter   Lizzeth         NaN
# 7   permitido  38c3ass9  16/03/2020 9:40:15  headquarter   Daniela         NaN
# 8   permitido  29c4aq34  17/03/2020 9:40:15  headquarter   Roberto         NaN
# 9   permitido  78c445as  18/03/2020 9:40:15  headquarter     Elias         NaN
# 10  permitido  45e734at  19/03/2020 9:40:15  headquarter     Maria         NaN
# 11  permitido  23e545as  20/03/2020 9:40:15  headquarter      Elsi         NaN
# 12  permitido  34e523et  21/03/2020 9:40:15  headquarter    Monica         NaN
# 13  permitido  12e889er  22/03/2020 9:40:15  headquarter   Angeles         NaN

# %% [markdown]
# # TRANSFORM - Transformar los datos que necesitamos

# %%
df3_union = pd.concat([df_drive, df_editar,],sort=True)
#definimos la union de los dataframe con uno nuevo para poder utilizar esa informacion

# %%
df3_union.describe
#de este modo podemos apreciar la informacion unida de los dos dataframe.
# Out:
# <bound method NDFrame.describe of        Access  Card UID                Date         From      Name  Unnamed: 0
# 0   permitido  41d716a3  09/03/2020 9:40:15  headquarter    Javier         0.0
# 1   permitido  40d817a6  10/03/2020 9:40:15  headquarter    Lucely         1.0
# 2   permitido  34d923a5  11/03/2020 9:40:15  headquarter  Santiago         2.0
# 3   permitido  12r623a5  12/03/2020 9:40:15  headquarter   Mildred         3.0
# 4   permitido  45v712a5  13/03/2020 9:40:15  headquarter      Lian         4.0
# 5   permitido  23c535s7  14/03/2020 9:40:15  headquarter     Josue         5.0
# 6   permitido  48c7ass9  15/03/2020 9:40:15  headquarter   Lizzeth         6.0
# 7   permitido  38c3ass9  16/03/2020 9:40:15  headquarter   Daniela         7.0
# 8   permitido  29c4aq34  17/03/2020 9:40:15  headquarter   Roberto         8.0
# 9   permitido  78c445as  18/03/2020 9:40:15  headquarter     Elias         9.0
# 10  permitido  45e734at  19/03/2020 9:40:15  headquarter     Maria        10.0
# 11  permitido  23e545as  20/03/2020 9:40:15  headquarter      Elsi        11.0
# 12  permitido  34e523et  21/03/2020 9:40:15  headquarter    Monica        12.0
# 13  permitido  12e889er  22/03/2020 9:40:15  headquarter   Angeles        13.0
# 0   permitido  41d716a3  09/03/2020 9:40:15  headquarter    Javier         NaN
# 1   permitido  40d817a6  10/03/2020 9:40:15  headquarter    Lucely         NaN
# 2   permitido  34d923a5  11/03/2020 9:40:15  headquarter  Santiago         NaN
# 3   permitido  12r623a5  12/03/2020 9:40:15  headquarter   Mildred         NaN
# 4   permitido  45v712a5  13/03/2020 9:40:15  headquarter      Lian         NaN
# 5   permitido  23c535s7  14/03/2020 9:40:15  headquarter     Josue         NaN
# 6   permitido  48c7ass9  15/03/2020 9:40:15  headquarter   Lizzeth         NaN
# 7   permitido  38c3ass9  16/03/2020 9:40:15  headquarter   Daniela         NaN
# 8   permitido  29c4aq34  17/03/2020 9:40:15  headquarter   Roberto         NaN
# 9   permitido  78c445as  18/03/2020 9:40:15  headquarter     Elias         NaN
# 10  permitido  45e734at  19/03/2020 9:40:15  headquarter     Maria         NaN
# 11  permitido  23e545as  20/03/2020 9:40:15  headquarter      Elsi         NaN
# 12  permitido  34e523et  21/03/2020 9:40:15  headquarter    Monica         NaN
# 13  permitido  12e889er  22/03/2020 9:40:15  headquarter   Angeles         NaN>

# %%
df3_union.dropna(axis =1)
#los datos anteriores cuentan con valores nulos, lo que hicimos fue eliminar esa columna con esos valores.
# Out:
#        Access  Card UID                Date         From      Name
# 0   permitido  41d716a3  09/03/2020 9:40:15  headquarter    Javier
# 1   permitido  40d817a6  10/03/2020 9:40:15  headquarter    Lucely
# 2   permitido  34d923a5  11/03/2020 9:40:15  headquarter  Santiago
# 3   permitido  12r623a5  12/03/2020 9:40:15  headquarter   Mildred
# 4   permitido  45v712a5  13/03/2020 9:40:15  headquarter      Lian
# 5   permitido  23c535s7  14/03/2020 9:40:15  headquarter     Josue
# 6   permitido  48c7ass9  15/03/2020 9:40:15  headquarter   Lizzeth
# 7   permitido  38c3ass9  16/03/2020 9:40:15  headquarter   Daniela
# 8   permitido  29c4aq34  17/03/2020 9:40:15  headquarter   Roberto
# 9   permitido  78c445as  18/03/2020 9:40:15  headquarter     Elias
# 10  permitido  45e734at  19/03/2020 9:40:15  headquarter     Maria
# 11  permitido  23e545as  20/03/2020 9:40:15  headquarter      Elsi
# 12  permitido  34e523et  21/03/2020 9:40:15  headquarter    Monica
# 13  permitido  12e889er  22/03/2020 9:40:15  headquarter   Angeles
# 0   permitido  41d716a3  09/03/2020 9:40:15  headquarter    Javier
# 1   permitido  40d817a6  10/03/2020 9:40:15  headquarter    Lucely
# 2   permitido  34d923a5  11/03/2020 9:40:15  headquarter  Santiago
# 3   permitido  12r623a5  12/03/2020 9:40:15  headquarter   Mildred
# 4   permitido  45v712a5  13/03/2020 9:40:15  headquarter      Lian
# 5   permitido  23c535s7  14/03/2020 9:40:15  headquarter     Josue
# 6   permitido  48c7ass9  15/03/2020 9:40:15  headquarter   Lizzeth
# 7   permitido  38c3ass9  16/03/2020 9:40:15  headquarter   Daniela
# 8   permitido  29c4aq34  17/03/2020 9:40:15  headquarter   Roberto
# 9   permitido  78c445as  18/03/2020 9:40:15  headquarter     Elias
# 10  permitido  45e734at  19/03/2020 9:40:15  headquarter     Maria
# 11  permitido  23e545as  20/03/2020 9:40:15  headquarter      Elsi
# 12  permitido  34e523et  21/03/2020 9:40:15  headquarter    Monica
# 13  permitido  12e889er  22/03/2020 9:40:15  headquarter   Angeles

# %%
df3_union. dtypes
#observamos que son de tipo object los datos
# Out:
# Access         object
# Card UID       object
# Date           object
# From           object
# Name           object
# Unnamed: 0    float64
# dtype: object

# %%
df3_union ['Name'] = df3_union ['Unnamed: 0']. astype (float)
df3_union ['Date'] = df3_union ['Unnamed: 0']. astype (float)

#convertimos la columna Name y Date en flotante

# %%
df3_union. dtypes
#podemos observar que ahora son flotantes
# Out:
# Access         object
# Card UID       object
# Date          float64
# From           object
# Name          float64
# Unnamed: 0    float64
# dtype: object

# %% [markdown]
# # LOAD - Cargar los datos que tenemos

# %%
from matplotlib import pyplot as plt 
#llama a la libreria de matplot
# %matplotlib inline  
#plotea en linea
import seaborn as sns 
#libreria para realizar graficas de manera matricial y detectar patrones

# %%
ploteo_nombre = df3_union[["Name"]]
ploteo_datos = df3_union[["Date"]]
#plotea numeros, no grafica texto

# %%
x = (ploteo_nombre)
y = (ploteo_datos)

plt.plot(x,y)
plt.xlabel('cantidad de Nombres ingresados RFDI')
plt.ylabel('Cantidad de Datos que accedieron')
plt.title('Registros RFID')
plt.show()

#en esta grafica podemos ver la cantidad de nombres que ingresan al cenote
#va incrementando, con forme la gente se va registrando.

# %%
# Modulos con los que trabajaremos para crear la grafica pero 3D
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

# Creamos la figura
fig = plt.figure()

# Agrrgamos un plano 3D
ax1 = fig.add_subplot(111,projection='3d')

# Datos en array bi-dimensional
x = (ploteo_nombre)
z = (ploteo_datos)

plt.xlabel('cantidad de Nombres ingresados RFDI')
plt.ylabel('Cantidad de Datos que accedieron')
plt.title('Registros RFID')




# plot_wireframe nos permite agregar los datos x, y, z. Por ello 3D
# Es necesario que los datos esten contenidos en un array bi-dimensional
ax1.plot_wireframe(x, y, z)

# Mostramos el gráfico
plt.show()
